# %% [markdown]
# ## Podcast Dataset
#
# ### By Alhanoof Alnajashi

# %% [markdown]
# ## Investigation Overview
#
# > The goal of this presentation is to get the visualizations easily and to be more understood.
#
# ## Dataset Overview
# > it has to CSV file podcast.csv and episodes.csv , in podcast.csv there are 9 attributes , in episodes.csv there are 7 attribute.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
Podcast = pd.read_csv('Podcast.csv')
English_Podcasts = pd.read_csv('English_Podcasts.csv')

# %% [markdown]
# ## (Visualization 1)
#
# > What are the top 3 categories in the English podcast?

# %%
Category = English_Podcasts['categories'].value_counts()[0:3]
plt.pie(Category, labels = Category.index, startangle = 90, autopct='%1.1f%%',counterclock = False);

# %% [markdown]
# ## (Visualization 2)
#
# > Let's discover the correlation between categories and length of the audio.

# %%
Ca = Podcast['categories'].value_counts()[0:5]
Le = Podcast['audio_length'].value_counts()[0:5]
sb.boxplot(data = Podcast, y = Ca.index, x = Le.index);

# %%
lan = Podcast['audio_length'].value_counts()[0:5]
cat = Podcast['categories'].value_counts()[0:5]
sb.countplot(data = Podcast, x = lan.index , hue = cat.index );

# %% [markdown]
# ## (Visualization 3)
#
# > The German podcast has the most content in the almost every categories.

# %%
g = sb.FacetGrid(data = Podcast, col = 'language', height = 3, col_wrap = 5)
g.map(plt.scatter, 'categories', 'audio_length', alpha = 1/3);
